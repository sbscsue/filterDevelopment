# %% [markdown]
# # test a Linear
# - https://www.notion.so/group-delay-filter-21c6e646601c4502a30e2d8a17a31386?pvs=4

# %%
# Packages and adjustments to the figures
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
plt.rcParams["figure.figsize"] = 10,5
plt.rcParams["font.size"] = 16

# %%
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# ## 1. read a test signal

# %%
# Generate a signal
y = pd.read_csv("data/Raw PPG data.csv").to_numpy().flatten()
samplingFreq = 500
tlims = np.array(list(range(0,len(y)))) / samplingFreq

# Compute the Fourier transform
yhat = np.fft.fft(y)
fcycles = np.fft.fftfreq(len(y),d=1.0/samplingFreq); # the frequencies in cycles/s

# Plot the signal
plt.figure()
plt.plot(tlims,y);
plt.ylabel("$y(t)$");
plt.xlabel("$t$ (s)");
plt.xlim([min(tlims),max(tlims)]);

# Plot the power spectrum
plt.figure()
plt.plot(fcycles,np.absolute(yhat));
plt.xlim([-100,100]);
plt.xlabel("$\omega$ (cycles/s)");
plt.ylabel("$|\hat{y}|$");
plt.show()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\_backend_tk.py", line 242, in resize
#     self.draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x0000021670E4E748>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x0000021670E4E748>

# %%
b = pd.read_csv("b.csv",header=None).to_numpy().flatten()

# %%
b
# Out:
# array([ 0.0000e+00, -3.8501e-06, -1.5525e-05, -3.5192e-05, -6.2990e-05,
#        -9.9032e-05, -1.4340e-04, -1.9615e-04, -2.5729e-04, -3.2683e-04,
#        -4.0472e-04, -4.9088e-04, -5.8522e-04, -6.8759e-04, -7.9783e-04,
#        -9.1573e-04, -1.0410e-03, -1.1735e-03, -1.3129e-03, -1.4587e-03,
#        -1.6108e-03, -1.7686e-03, -1.9317e-03, -2.0998e-03, -2.2723e-03,
#        -2.4487e-03, -2.6285e-03, -2.8111e-03, -2.9961e-03, -3.1827e-03,
#        -3.3703e-03, -3.5584e-03, -3.7463e-03, -3.9334e-03, -4.1189e-03,
#        -4.3022e-03, -4.4825e-03, -4.6593e-03, -4.8318e-03, -4.9993e-03,
#        -5.1611e-03, -5.3165e-03, -5.4649e-03, -5.6055e-03, -5.7377e-03,
#        -5.8608e-03, -5.9741e-03, -6.0772e-03, -6.1692e-03, -6.2498e-03,
#        -6.3182e-03, -6.3739e-03, -6.4165e-03, -6.4454e-03, -6.4602e-03,
#        -6.4605e-03, -6.4459e-03, -6.4161e-03, -6.3707e-03, -6.3094e-03,
#        -6.2320e-03, -6.1384e-03, -6.0284e-03, -5.9018e-03, -5.7586e-03,
#        -5.5989e-03, -5.4225e-03, -5.2297e-03, -5.0205e-03, -4.7951e-03,
#        -4.5536e-03, -4.2965e-03, -4.0239e-03, -3.7362e-03, -3.4338e-03,
#        -2.4487e-03, -2.2723e-03, -2.0998e-03, -1.9317e-03, -1.7686e-03,
#        -1.6108e-03, -1.4587e-03, -1.3129e-03, -1.1735e-03, -1.0410e-03,
#        -9.1573e-04, -7.9783e-04, -6.8759e-04, -5.8522e-04, -4.9088e-04,
#        -4.0472e-04, -3.2683e-04, -2.5729e-04, -1.9615e-04, -1.4340e-04,
#        -9.9032e-05, -6.2990e-05, -3.5192e-05, -1.5525e-05, -3.8501e-06,
#         0.0000e+00])

# %%
a = np.array([1])

# %%
a
# Out:
# array([1])

# %% [markdown]
# ## 4. Filter coefficients
#
# We want to find the filter coefficients for the discrete update:
# $$y[n] = a_1 y[n-1] + a_2 y[n-2] + ... + b_0 x[n] + b_1 x[n-1] + ...$$
#
# The coefficients can be taken directly from the discrete transfer function of the filter in the form:
# $$H(z) = \frac{b_0 + b_1 z^{-1} + b_2 z^{-2} + \ldots}{1 - a_1 z^{-1} - a_2 z^{-2} + \ldots}$$
#
# (This is a result of taking the Z-transform which is not shown here)
#
# Compare this to a transfer function with coefficients
# <code>
# num = [b_0, b_1, b_2]
# den = [1, a_1, a_2]
# </code>
# is
# $$H(z) = \frac{b_0 z^2 + b_1 z + b_2}{z^2 + a_1 z + a_2}$$
# which is equivalent to
# $$H(z) = \frac{b_0 + b_1 z^{-1} + b_2 z^{-2}}{1 + a_1 z^{-1} + a_2 z^{-2}}$$
# So you can take the coefficients in the same order that they are defined in the numerator and denominator of the transfer function object. The only difference is that the **coefficients in the denominator need a negative sign**.
#
# * To filter the signal, apply the filter using the discrete update
# * The filtered signal and filtered signal power spectrum are plotted alongside the unfiltered signal

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = 10,5
plt.rcParams["font.size"] = 16

# %%
# %matplotlib tk

# %%
# The coefficients from the discrete form of the filter transfer function (but with a negative sign)
print("Filter coefficients b_i: " + str(b))
#print("Filter coefficients a_i: " + str(a[0:]))

b = b
a = -a

# Filter the signal
yfilt = np.zeros(len(y))
for i in range(len(b),len(y)):
    for j in range(0,len(b),1):
        yfilt[i] += b[j]*y[i-j]
    
# Plot the signal
plt.figure()
plt.plot(y);
plt.plot(yfilt);
plt.plot(yfilt*50)
plt.plot([0,samplingFreq*5])
plt.ylabel("$y(t)$")
plt.show()

# Generate Fourier transform
yfilthat = np.fft.fft(yfilt)
fcycles = np.fft.fftfreq(len(y),d=1.0/samplingFreq)

plt.figure()
plt.plot(fcycles,np.absolute(yhat));
plt.plot(fcycles,np.absolute(yfilthat));
plt.xlim([-100,100]);
plt.xlabel("$\omega$ (cycles/s)");
plt.ylabel("$|\hat{y}|$");
plt.show()
# Out:
# Filter coefficients b_i: [ 0.0000e+00 -3.8501e-06 -1.5525e-05 -3.5192e-05 -6.2990e-05 -9.9032e-05
#  -5.4812e-04 -9.4854e-04 -1.3390e-03 -1.7187e-03 -2.0870e-03 -2.4432e-03
#  -2.7868e-03 -3.1172e-03 -3.4338e-03 -3.7362e-03 -4.0239e-03 -4.2965e-03
#  -4.5536e-03 -4.7951e-03 -5.0205e-03 -5.2297e-03 -5.4225e-03 -5.5989e-03
#  -5.7586e-03 -5.9018e-03 -6.0284e-03 -6.1384e-03 -6.2320e-03 -6.3094e-03
#  -6.3707e-03 -6.4161e-03 -6.4459e-03 -6.4605e-03 -6.4602e-03 -6.4454e-03
#  -6.4165e-03 -6.3739e-03 -6.3182e-03 -6.2498e-03 -6.1692e-03 -6.0772e-03
#  -5.9741e-03 -5.8608e-03 -5.7377e-03 -5.6055e-03 -5.4649e-03 -5.3165e-03
#  -5.1611e-03 -4.9993e-03 -4.8318e-03 -4.6593e-03 -4.4825e-03 -4.3022e-03
#  -4.1189e-03 -3.9334e-03 -3.7463e-03 -3.5584e-03 -3.3703e-03 -3.1827e-03
#  -2.9961e-03 -2.8111e-03 -2.6285e-03 -2.4487e-03 -2.2723e-03 -2.0998e-03
#  -1.9317e-03 -1.7686e-03 -1.6108e-03 -1.4587e-03 -1.3129e-03 -1.1735e-03
#  -1.0410e-03 -9.1573e-04 -7.9783e-04 -6.8759e-04 -5.8522e-04 -4.9088e-04
#  -4.0472e-04 -3.2683e-04 -2.5729e-04 -1.9615e-04 -1.4340e-04 -9.9032e-05
#  -6.2990e-05 -3.5192e-05 -1.5525e-05 -3.8501e-06  0.0000e+00]

# %% [markdown]
# # test peak detection

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = 10,5
plt.rcParams["font.size"] = 16

# %%
# %matplotlib tk

# %%
from scipy import signal

# %%
peaks_y , _= signal.find_peaks(y,distance=350)
peaks_filter , _ = signal.find_peaks(yfilt,distance=350)

# %%
plt.plot(y)
plt.plot(peaks_y,y[peaks_y],'ro')
plt.plot(yfilt)
plt.plot(peaks_filter,yfilt[peaks_filter],'bo')
plt.xlim([0,samplingFreq*10])
# Out:
# (0.0, 5000.0)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x00000215D7482080>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\_backend_tk.py", line 242, in resize
#     self.draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x00000215D7482080>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "c:\Users\kyj\anaconda3\envs\ml-cpu\lib\site-packages\matplotlib\backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x00000215D7482080>

# %%
for i in range(15):
    print(peaks_filter[i] - peaks_y[i])
# Out:
# 557
# 582
# 578
# 541
# 561
# 582
# 573
# 561
# 580
# 587
# 561
# 570
# 574
# 573
# 551
